# %% [markdown]
# # Importing modules

# %%
# %load_ext sql

# %%
import cx_Oracle

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # Connecting to Database

# %%
# %sql oracle+cx_oracle://projectsds:24689@127.0.0.1:8080/?xe
# Out:
# 'Connected: Projects@'

# %% [markdown]
# # Exploring Dataset

# %% [markdown]
# ## First dataset

# %%
# %sql select column_name,data_type from user_tab_cols where table_name='DATASET1'
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('ID', 'NUMBER'),
#  ('DISTRICT', 'VARCHAR2'),
#  ('STATE', 'VARCHAR2'),
#  ('GROWTH', 'NUMBER'),
#  ('SEX_RATIO', 'VARCHAR2'),
#  ('LITERACY', 'NUMBER')]

# %%
# %sql select * from dataset1
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [(170, 'Gurgaon', 'Haryana', Decimal('0.74'), '854.00', Decimal('84.7')),
#  (171, 'Karnal', 'Haryana', Decimal('0.18'), '887.00', Decimal('74.73')),
#  (172, 'Sonipat', 'Haryana', Decimal('0.13'), '856.00', Decimal('79.12')),
#  (173, 'Jind', 'Haryana', Decimal('0.12'), '871.00', Decimal('71.44')),
#  (174, 'Sirsa', 'Haryana', Decimal('0.16'), '897.00', Decimal('68.82')),
#  (175, 'Yamunanagar', 'Haryana', Decimal('0.17'), '877.00', Decimal('77.99')),
#  (176, 'Panipat', 'Haryana', Decimal('0.25'), '864.00', Decimal('75.94')),
#  (177, 'Ambala', 'Haryana', Decimal('0.11'), '885.00', Decimal('81.75')),
#  (178, 'Mewat', 'Haryana', Decimal('0.38'), '907.00', Decimal('54.08')),
#  (179, 'Kaithal', 'Haryana', Decimal('0.14'), '881.00', Decimal('69.15')),
#  (180, 'Rohtak', 'Haryana', Decimal('0.13'), '867.00', Decimal('80.22')),
#  (181, 'Palwal', 'Haryana', Decimal('0.26'), '880.00', Decimal('69.32')),
# ...

# %%
# %sql select count(*) as total_record from dataset1
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [(640,)]

# %% [markdown]
# ## Second dataset

# %%
# %sql select column_name,data_type from user_tab_cols where table_name='DATASET2'
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('ID', 'NUMBER'),
#  ('DISTRICT_CODE', 'NUMBER'),
#  ('STATE_NAME', 'VARCHAR2'),
#  ('DISTRICT_NAME', 'VARCHAR2'),
#  ('POPULATION', 'NUMBER'),
#  ('MALE', 'NUMBER'),
#  ('FEMALE', 'NUMBER'),
#  ('LITERATE', 'NUMBER'),
#  ('MALE_LITERATE', 'NUMBER'),
#  ('FEMALE_LITERATE', 'NUMBER'),
#  ('SC', 'NUMBER'),
#  ('MALE_SC', 'NUMBER'),
#  ('FEMALE_SC', 'NUMBER'),
#  ('ST', 'NUMBER'),
#  ('MALE_ST', 'NUMBER'),
#  ('FEMALE_ST', 'NUMBER'),
#  ('WORKERS', 'NUMBER'),
#  ('MALE_WORKERS', 'NUMBER'),
#  ('FEMALE_WORKERS', 'NUMBER'),
#  ('MAIN_WORKERS', 'NUMBER')]

# %%
# %sql select * from dataset2
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [(133, 133, 'UTTAR PRADESH', 'Muzaffarnagar', 4143512, 2193434, 1950078, 2417339, 1448528, 968811, 561250, 298587, 262663, 317, 176, 141, 1291644, 1081569, 210075, 1085491),
#  (134, 134, 'UTTAR PRADESH', 'Bijnor', 3682713, 1921215, 1761498, 2135393, 1241471, 893922, 787444, 413872, 373572, 3058, 1588, 1470, 1088036, 921497, 166539, 839778),
#  (135, 135, 'UTTAR PRADESH', 'Moradabad', 4772006, 2503186, 2268820, 2263848, 1357435, 906413, 731406, 385244, 346162, 685, 377, 308, 1417811, 1193439, 224372, 1104968),
#  (136, 136, 'UTTAR PRADESH', 'Rampur', 2335819, 1223889, 1111930, 1043666, 630408, 413258, 307936, 162844, 145092, 358, 207, 151, 737261, 609693, 127568, 564266),
#  (137, 137, 'UTTAR PRADESH', 'Jyotiba Phule Nagar', 1840221, 963449, 876772, 983110, 600541, 382569, 318001, 166662, 151339, 164, 89, 75, 599089, 459037, 140052, 453567),
# ...

# %%
# %sql select count(*) as total_records from dataset2
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [(640,)]

# %% [markdown]
# # Data Analysis and Visualizations

# %% [markdown]
# ## Population of India

# %%
# %sql select sum(population) as Total_Population from dataset2
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [(1210854977,)]

# %% [markdown]
# ## Avg growth of India

# %%
# %sql select trunc(avg(growth)*100,2) as avg_growth from dataset1
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [(Decimal('19.26'),)]

# %% [markdown]
# ## Data of Jharkhand and Bihar

# %%
# %sql select * from Dataset1 where state in ('Jharkhand','Bihar')
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [(222, 'Ranchi', 'Jharkhand', Decimal('0.24'), '949.00', Decimal('76.06')),
#  (223, 'Dhanbad', 'Jharkhand', Decimal('0.12'), '909.00', Decimal('74.52')),
#  (224, 'Giridih', 'Jharkhand', Decimal('0.28'), '944.00', Decimal('63.14')),
#  (225, 'Purbi Singhbhum', 'Jharkhand', Decimal('0.16'), '949.00', Decimal('75.49')),
#  (226, 'Bokaro', 'Jharkhand', Decimal('0.16'), '922.00', Decimal('72.01')),
#  (227, 'Palamu', 'Jharkhand', Decimal('0.26'), '928.00', Decimal('63.63')),
#  (228, 'Hazaribagh', 'Jharkhand', Decimal('0.21'), '947.00', Decimal('69.75')),
#  (229, 'Pashchimi Singhbhum', 'Jharkhand', Decimal('0.22'), '"1,005.00"', Decimal('58.63')),
#  (230, 'Deoghar', 'Jharkhand', Decimal('0.28'), '925.00', Decimal('64.85')),
#  (231, 'Garhwa', 'Jharkhand', Decimal('0.28'), '935.00', Decimal('60.33')),
#  (232, 'Dumka', 'Jharkhand', Decimal('0.19'), '977.00', Decimal('61.02')),
# ...

# %% [markdown]
# ## Total district of each state in India

# %%
r=%sql select state,count(*) as total_number_of_district from dataset1 group by state
r
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Jammu and Kashmir', 22),
#  ('Maharashtra', 35),
#  ('Madhya Pradesh', 50),
#  ('Orissa', 30),
#  ('Sikkim', 4),
#  ('Bihar', 38),
#  ('Chandigarh', 1),
#  ('Haryana', 21),
#  ('Himachal Pradesh', 12),
#  ('Jharkhand', 24),
#  ('Rajasthan', 33),
#  ('Tamil Nadu', 32),
#  ('Chhattisgarh', 18),
#  ('Delhi', 9),
#  ('Gujarat', 26),
#  ('Manipur', 9),
#  ('Mizoram', 8),
#  ('Nagaland', 11),
#  ('Puducherry', 4),
#  ('Tripura', 4),
#  ('Dadra and Nagar Haveli', 1),
#  ('Goa', 2),
#  ('Karnataka', 30),
#  ('Uttar Pradesh', 71),
#  ('Andhra Pradesh', 23),
#  ('Arunachal Pradesh', 16),
#  ('Assam', 27),
#  ('Uttarakhand', 13),
#  ('Daman and Diu', 2),
#  ('Punjab', 20),
#  ('Andaman And Nicobar Islands', 3),
#  ('Kerala', 14),
#  ('Lakshadweep', 1),
#  ('Meghalaya', 7),
#  ('West Bengal', 19)]

# %%
df=r.DataFrame()
plt.figure(figsize=(8,8))
plt.title('Total districts in each state',size=20)
plt.barh(df['state'],df['total_number_of_district'],color=['r','y','grey','g','b'],edgecolor='k')
plt.ylabel('State')
plt.xlabel('No. of districts')
plt.show()

# %% [markdown]
# ## State-wise growth rate

# %%
r=%sql select state,trunc(avg(growth)*100,2) as avg_growth_rate from dataset1 group by state
r
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Jammu and Kashmir', Decimal('24.36')),
#  ('Maharashtra', Decimal('13.88')),
#  ('Madhya Pradesh', Decimal('20.28')),
#  ('Orissa', Decimal('14.23')),
#  ('Sikkim', Decimal('11.5')),
#  ('Bihar', Decimal('25.21')),
#  ('Chandigarh', 17),
#  ('Haryana', Decimal('20.57')),
#  ('Himachal Pradesh', Decimal('11.41')),
#  ('Jharkhand', Decimal('23.75')),
#  ('Rajasthan', Decimal('21.18')),
#  ('Tamil Nadu', Decimal('14.68')),
#  ('Chhattisgarh', Decimal('20.05')),
#  ('Delhi', 14),
#  ('Gujarat', Decimal('17.11')),
#  ('Manipur', Decimal('25.66')),
#  ('Mizoram', Decimal('24.5')),
#  ('Nagaland', Decimal('82.27')),
#  ('Puducherry', Decimal('34.25')),
#  ('Tripura', Decimal('16.75')),
#  ('Dadra and Nagar Haveli', 56),
#  ('Goa', Decimal('8.5')),
#  ('Karnataka', Decimal('11.86')),
#  ('Uttar Pradesh', Decimal('20.04')),
#  ('Andhra Pradesh', Decimal('10.86')),
#  ('Arunachal Pradesh', Decimal('27.93')),
# ...

# %%
df=r.DataFrame()
plt.figure(figsize=(8,8))
plt.title('State-wise growth rate',size=20)
plt.barh(df['state'],df['avg_growth_rate'],color=['r','y','grey','g','b'],edgecolor='k')
plt.ylabel('State')
plt.xlabel('Avg growth rate')
plt.show()

# %% [markdown]
# ## Top 10 states in growth rate

# %%
r=%sql select * from (select state,trunc(avg(growth)*100,2) as avg_growth_rate from dataset1 group by state order by avg_growth_rate desc) where rownum <=10
r
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Nagaland', Decimal('82.27')),
#  ('Dadra and Nagar Haveli', 56),
#  ('Daman and Diu', 43),
#  ('Puducherry', Decimal('34.25')),
#  ('Meghalaya', Decimal('30.42')),
#  ('Arunachal Pradesh', Decimal('27.93')),
#  ('Manipur', Decimal('25.66')),
#  ('Bihar', Decimal('25.21')),
#  ('Mizoram', Decimal('24.5')),
#  ('Jammu and Kashmir', Decimal('24.36'))]

# %%
df=r.DataFrame()
plt.pie(df['avg_growth_rate'],autopct='%0.2f%%',labels=df['state'])
plt.title('Top 10 states in growth rate',size=15)
plt.show()

# %% [markdown]
# ## Bottom 10 states in growth rate

# %%
# %%sql
# select * from (select state,trunc(avg(growth)*100,2) as avg_growth_rate from dataset1 group by state order by avg_growth_rate)
# where rownum <=10
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Andaman And Nicobar Islands', Decimal('0.66')),
#  ('Kerala', Decimal('4.14')),
#  ('Lakshadweep', 6),
#  ('Goa', Decimal('8.5')),
#  ('Andhra Pradesh', Decimal('10.86')),
#  ('Himachal Pradesh', Decimal('11.41')),
#  ('Sikkim', Decimal('11.5')),
#  ('Karnataka', Decimal('11.86')),
#  ('Uttarakhand', Decimal('13.15')),
#  ('Punjab', Decimal('13.55'))]

# %% [markdown]
# ### Convert sex ratio from varchar to number

# %%
# %sql alter table dataset1 add sexratio number
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# []

# %%
# %sql update dataset1 set sexratio=to_number(replace ((replace(sex_ratio,'"','')),',',''))
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 640 rows affected.
# []

# %%
# %sql select sexratio from dataset1
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [(854,),
#  (887,),
#  (856,),
#  (871,),
#  (897,),
#  (877,),
#  (864,),
#  (885,),
#  (907,),
#  (881,),
#  (867,),
#  (880,),
#  (888,),
#  (862,),
#  (902,),
#  (895,),
#  (898,),
#  (873,),
#  (1012,),
#  (1007,),
#  (915,),
#  (880,),
#  (918,),
#  (976,),
#  (986,),
#  (1095,),
#  (942,),
#  (981,),
#  (819,),
#  (903,),
#  (880,),
#  (900,),
#  (927,),
#  (885,),
#  (835,),
#  (894,),
#  (860,),
#  (890,),
#  (912,),
#  (870,),
#  (893,),
#  (951,),
#  (919,),
#  (889,),
#  (886,),
#  (890,),
#  (874,),
#  (902,),
#  (951,),
#  (920,),
#  (810,),
#  (690,),
#  (949,),
#  (909,),
#  (944,),
#  (949,),
#  (922,),
#  (928,),
#  (947,),
#  (1005,),
#  (925,),
#  (935,),
#  (977,),
#  (938,),
#  (952,),
#  (956,),
#  (953,),
#  (993,),
#  (921,),
#  (989,),
#  (954,),
#  (967,),
#  (950,),
#  (997,),
#  (997,),
#  (985,),
#  (916,),
#  (973,),
#  (985,),
#  (984,),
#  (971,),
#  (983,),
#  (960,),
# ...

# %%
# %sql alter table dataset1 drop column sex_ratio
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# []

# %% [markdown]
# ## State-wise sex ratio

# %%
r=%sql select state,round(avg(sexratio))as avg_sexratio from dataset1 group by state
r
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Jammu and Kashmir', 883),
#  ('Maharashtra', 948),
#  ('Madhya Pradesh', 936),
#  ('Orissa', 984),
#  ('Sikkim', 874),
#  ('Bihar', 918),
#  ('Chandigarh', 818),
#  ('Haryana', 880),
#  ('Himachal Pradesh', 953),
#  ('Jharkhand', 956),
#  ('Rajasthan', 930),
#  ('Tamil Nadu', 999),
#  ('Chhattisgarh', 995),
#  ('Delhi', 866),
#  ('Gujarat', 938),
#  ('Manipur', 976),
#  ('Mizoram', 966),
#  ('Nagaland', 934),
#  ('Puducherry', 1075),
#  ('Tripura', 958),
#  ('Dadra and Nagar Haveli', 774),
#  ('Goa', 975),
#  ('Karnataka', 984),
#  ('Uttar Pradesh', 909),
#  ('Andhra Pradesh', 995),
#  ('Arunachal Pradesh', 920),
#  ('Assam', 958),
#  ('Uttarakhand', 1010),
#  ('Daman and Diu', 783),
#  ('Punjab', 897),
#  ('Andaman And Nicobar Islands', 858),
#  ('Kerala', 1080),
#  ('Lakshadweep', 946),
#  ('Meghalaya', 980),
#  ('West Bengal', 950)]

# %%
df=r.DataFrame()
plt.figure(figsize=(8,8))
plt.title('State-wise sex ratio',size=20)
plt.barh(df['state'],df['avg_sexratio'],color=['r','y','grey','g','b'],edgecolor='k')
plt.ylabel('State')
plt.xlabel('Avg sex ratio')
plt.show()

# %% [markdown]
# ## Top 10 states in sex ratio

# %%
r=%sql select * from(select state,round(avg(sexratio))as avg_sexratio from dataset1 group by state order by avg_sexratio desc) where rownum<=10
r
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Kerala', 1080),
#  ('Puducherry', 1075),
#  ('Uttarakhand', 1010),
#  ('Tamil Nadu', 999),
#  ('Chhattisgarh', 995),
#  ('Andhra Pradesh', 995),
#  ('Orissa', 984),
#  ('Karnataka', 984),
#  ('Meghalaya', 980),
#  ('Manipur', 976)]

# %%
df=r.DataFrame()
plt.pie(df['avg_sexratio'],autopct='%0.2f',labels=df['state'])
plt.title('Top 10 states in sex ratio',size=15)
plt.show()

# %% [markdown]
# ## Bottom 10 states in sex ratio

# %%
r=%sql select * from(select state,round(avg(sexratio))as avg_sexratio from dataset1 group by state order by avg_sexratio) where rownum<=10
r
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Dadra and Nagar Haveli', 774),
#  ('Daman and Diu', 783),
#  ('Chandigarh', 818),
#  ('Andaman And Nicobar Islands', 858),
#  ('Delhi', 866),
#  ('Sikkim', 874),
#  ('Haryana', 880),
#  ('Jammu and Kashmir', 883),
#  ('Punjab', 897),
#  ('Uttar Pradesh', 909)]

# %% [markdown]
# ## State-wise literacy rate

# %%
r=%sql select state,trunc(avg(literacy),2)as avg_literacy_rate from dataset1 group by state
r
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Jammu and Kashmir', Decimal('65.37')),
#  ('Maharashtra', Decimal('80.96')),
#  ('Madhya Pradesh', Decimal('67.68')),
#  ('Orissa', Decimal('70.83')),
#  ('Sikkim', Decimal('80.16')),
#  ('Bihar', Decimal('61.75')),
#  ('Chandigarh', Decimal('86.05')),
#  ('Haryana', Decimal('75.35')),
#  ('Himachal Pradesh', Decimal('81.74')),
#  ('Jharkhand', Decimal('64.74')),
#  ('Rajasthan', Decimal('64.6')),
#  ('Tamil Nadu', Decimal('79.33')),
#  ('Chhattisgarh', Decimal('65.84')),
#  ('Delhi', Decimal('86.55')),
#  ('Gujarat', Decimal('76.38')),
#  ('Manipur', Decimal('76.36')),
#  ('Mizoram', Decimal('89.36')),
#  ('Nagaland', Decimal('78.39')),
#  ('Puducherry', Decimal('87.45')),
#  ('Tripura', Decimal('86.64')),
#  ('Dadra and Nagar Haveli', Decimal('76.24')),
#  ('Goa', Decimal('88.58')),
#  ('Karnataka', Decimal('73.65')),
#  ('Uttar Pradesh', Decimal('67.5')),
#  ('Andhra Pradesh', Decimal('66.29')),
# ...

# %%
df=r.DataFrame()
plt.figure(figsize=(8,8))
plt.title('State-wise literacy rate',size=20)
plt.barh(df['state'],df['avg_literacy_rate'],color=['r','y','grey','g','b'],edgecolor='k')
plt.ylabel('State')
plt.xlabel('Avg literacy rate')
plt.show()

# %% [markdown]
# ## Top 10 states in literacy rate

# %%
r=%sql select * from(select state, trunc(avg(literacy),2)as avg_literacy_rate from dataset1 group by state order by avg_literacy_rate desc) where rownum<=10
r
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Kerala', Decimal('93.69')),
#  ('Lakshadweep', Decimal('91.85')),
#  ('Mizoram', Decimal('89.36')),
#  ('Goa', Decimal('88.58')),
#  ('Puducherry', Decimal('87.45')),
#  ('Tripura', Decimal('86.64')),
#  ('Delhi', Decimal('86.55')),
#  ('Chandigarh', Decimal('86.05')),
#  ('Daman and Diu', Decimal('85.76')),
#  ('Andaman And Nicobar Islands', Decimal('83.7'))]

# %%
df=r.DataFrame()
plt.pie(df['avg_literacy_rate'],autopct='%0.2f',labels=df['state'])
plt.title('Top 10 states in literacy rate',size=15)
plt.show()

# %% [markdown]
# ## Bottom 10 states in literacy rate

# %%
# %%sql
# select * from(select state, trunc(avg(literacy),2)as avg_literacy_rate from dataset1 group by state order by
# avg_literacy_rate) where rownum<=10
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Bihar', Decimal('61.75')),
#  ('Arunachal Pradesh', Decimal('63.86')),
#  ('Rajasthan', Decimal('64.6')),
#  ('Jharkhand', Decimal('64.74')),
#  ('Jammu and Kashmir', Decimal('65.37')),
#  ('Chhattisgarh', Decimal('65.84')),
#  ('Andhra Pradesh', Decimal('66.29')),
#  ('Uttar Pradesh', Decimal('67.5')),
#  ('Madhya Pradesh', Decimal('67.68')),
#  ('Orissa', Decimal('70.83'))]

# %% [markdown]
# ## State having literacy rate >90%

# %%
# %%sql
# select state, trunc(avg(literacy),2)as avg_literacy_rate from dataset1 group by state having trunc(avg(literacy),2)>90
# order by avg_literacy_rate desc
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Kerala', Decimal('93.69')), ('Lakshadweep', Decimal('91.85'))]

# %% [markdown]
# ## Top and bottom 3 states in literacy rate

# %%
# %%sql
# select * from (select state,trunc(avg(literacy),2) as avg_literacy_rate from dataset1 group by state
#                order by avg_literacy_rate desc) where rownum<=3
# union all
# select * from (select state,trunc(avg(literacy),2) as avg_literacy_rate from dataset1 group by state
#                order by avg_literacy_rate) where rownum<=3
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Kerala', Decimal('93.69')),
#  ('Lakshadweep', Decimal('91.85')),
#  ('Mizoram', Decimal('89.36')),
#  ('Bihar', Decimal('61.75')),
#  ('Arunachal Pradesh', Decimal('63.86')),
#  ('Rajasthan', Decimal('64.6'))]

# %% [markdown]
# ## State starting with the letter 'A'

# %%
# %sql select distinct(state) from dataset1 where upper(state) like 'A%'
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Andhra Pradesh',),
#  ('Arunachal Pradesh',),
#  ('Assam',),
#  ('Andaman And Nicobar Islands',)]

# %% [markdown]
# ## State starting with the letter 'A' or 'B'

# %%
# %sql select distinct(state) from dataset1 where upper(state) like 'A%' or upper(state) like'B%'
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Bihar',),
#  ('Andhra Pradesh',),
#  ('Arunachal Pradesh',),
#  ('Assam',),
#  ('Andaman And Nicobar Islands',)]

# %% [markdown]
# ## State starting with the letter 'A' and ending with 'M'

# %%
# %sql select distinct(state) from dataset1 where upper(state) like 'A%M'
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Assam',)]

# %% [markdown]
# ## Basic information about Indian districts

# %%
# %%sql
# select d1.state,d1.district,d1.sexratio,d2.population from dataset1 d1 inner join dataset2 d2
# on d1.district=d2.district_name
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Haryana', 'Gurgaon', 854, 1514432),
#  ('Haryana', 'Karnal', 887, 1505324),
#  ('Haryana', 'Sonipat', 856, 1450001),
#  ('Haryana', 'Jind', 871, 1334152),
#  ('Haryana', 'Sirsa', 897, 1295189),
#  ('Haryana', 'Yamunanagar', 877, 1214205),
#  ('Haryana', 'Panipat', 864, 1205437),
#  ('Haryana', 'Ambala', 885, 1128350),
#  ('Haryana', 'Mewat', 907, 1089263),
#  ('Haryana', 'Kaithal', 881, 1074304),
#  ('Haryana', 'Rohtak', 867, 1061204),
#  ('Haryana', 'Palwal', 880, 1042708),
#  ('Haryana', 'Kurukshetra', 888, 964655),
#  ('Haryana', 'Jhajjar', 862, 958405),
#  ('Haryana', 'Fatehabad', 902, 942011),
#  ('Haryana', 'Mahendragarh', 895, 922088),
#  ('Haryana', 'Rewari', 898, 900332),
#  ('Haryana', 'Panchkula', 873, 561293),
#  ('Himachal Pradesh', 'Kangra', 1012, 1510075),
#  ('Himachal Pradesh', 'Mandi', 1007, 999777),
#  ('Himachal Pradesh', 'Shimla', 915, 814010),
# ...

# %% [markdown]
# ## Basic information about Indian states

# %%
# %%sql
# select state,round(avg(sexratio)) as avg_sexratio,sum(population)as total_population from
# (select d1.state,d1.district,d1.sexratio,d2.population from dataset1 d1 inner join dataset2 d2
# on d1.district=d2.district_name) group by state
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Jammu and Kashmir', 892, 12015583),
#  ('Maharashtra', 951, 113322979),
#  ('Madhya Pradesh', 936, 67681327),
#  ('Orissa', 984, 41974218),
#  ('Bihar', 919, 101074979),
#  ('Chandigarh', 818, 1055450),
#  ('Haryana', 880, 25351462),
#  ('Himachal Pradesh', 970, 10600952),
#  ('Jharkhand', 956, 31923078),
#  ('Rajasthan', 932, 71757578),
#  ('Tamil Nadu', 999, 72147030),
#  ('Chhattisgarh', 992, 26354956),
#  ('Delhi', 822, 142004),
#  ('Gujarat', 937, 52499821),
#  ('Manipur', 976, 2855794),
#  ('Mizoram', 966, 1097206),
#  ('Nagaland', 934, 1978502),
#  ('Puducherry', 1090, 297664),
#  ('Tripura', 958, 3673917),
#  ('Goa', 975, 1458545),
#  ('Karnataka', 984, 61350527),
#  ('Uttar Pradesh', 908, 185756690),
#  ('Andhra Pradesh', 995, 81698308),
#  ('Arunachal Pradesh', 916, 1207154),
#  ('Assam', 958, 31205576),
#  ('Uttarakhand', 1014, 7508599),
#  ('Daman and Diu', 783, 243247),
# ...

# %% [markdown]
# ## District-wise, total male and female

# %%
# %%sql
# select state,district,population,(population-total_female) as total_male,total_female from
# (select d1.state,d1.district,d2.population,round(((d1.sexratio/1000)*d2.population)/(1+(d1.sexratio/1000)))
#  as total_female from dataset1 d1 inner join dataset2 d2 on d1.district=d2.district_name)
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Haryana', 'Gurgaon', 1514432, 816846, 697586),
#  ('Haryana', 'Karnal', 1505324, 797734, 707590),
#  ('Haryana', 'Sonipat', 1450001, 781251, 668750),
#  ('Haryana', 'Jind', 1334152, 713069, 621083),
#  ('Haryana', 'Sirsa', 1295189, 682756, 612433),
#  ('Haryana', 'Yamunanagar', 1214205, 646886, 567319),
#  ('Haryana', 'Panipat', 1205437, 646694, 558743),
#  ('Haryana', 'Ambala', 1128350, 598594, 529756),
#  ('Haryana', 'Mewat', 1089263, 571192, 518071),
#  ('Haryana', 'Kaithal', 1074304, 571135, 503169),
#  ('Haryana', 'Rohtak', 1061204, 568401, 492803),
#  ('Haryana', 'Palwal', 1042708, 554632, 488076),
#  ('Haryana', 'Kurukshetra', 964655, 510940, 453715),
#  ('Haryana', 'Jhajjar', 958405, 514718, 443687),
#  ('Haryana', 'Fatehabad', 942011, 495274, 446737),
#  ('Haryana', 'Mahendragarh', 922088, 486590, 435498),
#  ('Haryana', 'Rewari', 900332, 474358, 425974),
# ...

# %% [markdown]
# ## State-wise, total male and female

# %%
# %%sql
# select state,sum(population)as Total_population,sum(total_male) as total_male,sum(total_female) as total_female from
# (select state,district,population,(population-total_female) as total_male,total_female from
# (select d1.state,d1.district,d2.population,round(((d1.sexratio/1000)*d2.population)/(1+(d1.sexratio/1000)))
#  as total_female from dataset1 d1 inner join dataset2 d2 on d1.district=d2.district_name))group by state
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Jammu and Kashmir', 12015583, 6353977, 5661606),
#  ('Maharashtra', 113322979, 58641586, 54681393),
#  ('Madhya Pradesh', 67681327, 35047689, 32633638),
#  ('Orissa', 41974218, 21212240, 20761978),
#  ('Bihar', 101074979, 52671313, 48403666),
#  ('Chandigarh', 1055450, 580556, 474894),
#  ('Haryana', 25351462, 13495175, 11856287),
#  ('Himachal Pradesh', 10600952, 5337119, 5263833),
#  ('Jharkhand', 31923078, 16386367, 15536711),
#  ('Rajasthan', 71757578, 37170091, 34587487),
#  ('Tamil Nadu', 72147030, 36139417, 36007613),
#  ('Chhattisgarh', 26354956, 13247177, 13107779),
#  ('Delhi', 142004, 77939, 64065),
#  ('Gujarat', 52499821, 27411309, 25088512),
#  ('Manipur', 2855794, 1438659, 1417135),
#  ('Mizoram', 1097206, 555336, 541870),
#  ('Nagaland', 1978502, 1024777, 953725),
#  ('Puducherry', 297664, 144253, 153411),
#  ('Tripura', 3673917, 1874564, 1799353),
#  ('Goa', 1458545, 739239, 719306),
# ...

# %%
r=%sql select * from(select state,sum(population)as Total_population,sum(total_male) as total_male,sum(total_female) as total_female from(select state,district,population,(population-total_female) as total_male,total_female from(select d1.state,d1.district,d2.population,round(((d1.sexratio/1000)*d2.population)/(1+(d1.sexratio/1000))) as total_female from dataset1 d1 inner join dataset2 d2 on d1.district=d2.district_name))group by state order by total_population desc) where rownum<=5
df=r.DataFrame()
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
plt.title('Percentage of males in the 5 most populated states',size=16)
plt.scatter(df['state'],(df['total_male']/df['total_population'])*100,marker='*',c='g',s=100)
plt.ticklabel_format(style='plain',axis='y')
plt.xlabel('State',size=12)
plt.ylabel('% of male',size=12)
plt.subplot(1,2,2)
plt.title('Percentage of females in the 5 most populated states',size=16)
plt.scatter(df['state'],(df['total_female']/df['total_population'])*100,marker='.',c='r',s=100)
plt.ticklabel_format(style='plain',axis='y')
plt.xlabel('State',size=12)
plt.ylabel('% of female',size=12)
plt.show()
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.

# %% [markdown]
# ## District-wise total literates and illiterates

# %%
# %%sql
# select d1.state,d1.district,d1.literacy as avg_literacy_rate,d2.population as total_population,
# round((d2.population*d1.literacy)/100)as total_literates,round((d2.population*(100-d1.literacy))/100)as
# total_illiterates from dataset1 d1 inner join dataset2 d2 on d1.district=d2.district_name
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Haryana', 'Gurgaon', Decimal('84.7'), 1514432, 1282724, 231708),
#  ('Haryana', 'Karnal', Decimal('74.73'), 1505324, 1124929, 380395),
#  ('Haryana', 'Sonipat', Decimal('79.12'), 1450001, 1147241, 302760),
#  ('Haryana', 'Jind', Decimal('71.44'), 1334152, 953118, 381034),
#  ('Haryana', 'Sirsa', Decimal('68.82'), 1295189, 891349, 403840),
#  ('Haryana', 'Yamunanagar', Decimal('77.99'), 1214205, 946958, 267247),
#  ('Haryana', 'Panipat', Decimal('75.94'), 1205437, 915409, 290028),
#  ('Haryana', 'Ambala', Decimal('81.75'), 1128350, 922426, 205924),
#  ('Haryana', 'Mewat', Decimal('54.08'), 1089263, 589073, 500190),
#  ('Haryana', 'Kaithal', Decimal('69.15'), 1074304, 742881, 331423),
#  ('Haryana', 'Rohtak', Decimal('80.22'), 1061204, 851298, 209906),
#  ('Haryana', 'Palwal', Decimal('69.32'), 1042708, 722805, 319903),
#  ('Haryana', 'Kurukshetra', Decimal('76.31'), 964655, 736128, 228527),
# ...

# %% [markdown]
# ## State-wise total literates and illiterates

# %%
# %%sql
# select state,sum(total_population) as total_population,trunc(avg(avg_literacy_rate),2)as avg_literacy_rate,
# sum(total_literates)as total_literates,sum(total_illiterates)as total_illiterates from
# (select d1.state,d1.district,d1.literacy as avg_literacy_rate,d2.population as total_population,
# round((d2.population*d1.literacy)/100)as total_literates,round((d2.population*(100-d1.literacy))/100)as
# total_illiterates from dataset1 d1 inner join dataset2 d2 on d1.district=d2.district_name)group by state
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Jammu and Kashmir', 12015583, Decimal('65.24'), 8067350, 3948233),
#  ('Maharashtra', 113322979, Decimal('80.74'), 92954049, 20368930),
#  ('Madhya Pradesh', 67681327, Decimal('67.9'), 47069447, 20611880),
#  ('Orissa', 41974218, Decimal('70.83'), 30486803, 11487415),
#  ('Bihar', 101074979, Decimal('61.94'), 62866536, 38208443),
#  ('Chandigarh', 1055450, Decimal('86.05'), 908215, 147235),
#  ('Haryana', 25351462, Decimal('75.35'), 19123489, 6227973),
#  ('Himachal Pradesh', 10600952, Decimal('82.83'), 8883924, 1717028),
#  ('Jharkhand', 31923078, Decimal('64.61'), 21132066, 10791012),
#  ('Rajasthan', 71757578, Decimal('64.34'), 47063500, 24694078),
#  ('Tamil Nadu', 72147030, Decimal('79.33'), 57775522, 14371508),
#  ('Chhattisgarh', 26354956, Decimal('65.81'), 18120647, 8234309),
#  ('Delhi', 142004, Decimal('88.34'), 125446, 16558),
#  ('Gujarat', 52499821, Decimal('77.13'), 41511336, 10988485),
# ...

# %%
r=%sql select * from(select state,sum(total_population) as total_population,trunc(avg(avg_literacy_rate),2)as avg_literacy_rate,sum(total_literates)as total_literates,sum(total_illiterates)as total_illiterates from(select d1.state,d1.district,d1.literacy as avg_literacy_rate,d2.population as total_population,round((d2.population*d1.literacy)/100)as total_literates,round((d2.population*(100-d1.literacy))/100)as total_illiterates from dataset1 d1 inner join dataset2 d2 on d1.district=d2.district_name)group by state order by total_population desc)where rownum<=5
df=r.DataFrame()
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
plt.title('Literacy rate in the 5 most populated states',size=18)
plt.scatter(df['state'],df['avg_literacy_rate'],marker='*',c='y',s=100)
plt.ticklabel_format(style='plain',axis='y')
plt.xlabel('State',size=12)
plt.ylabel('Literacy rate',size=12)
plt.subplot(1,2,2)
plt.title('Illiteracy rate in the 5 most populated states',size=18)
plt.scatter(df['state'],100-df['avg_literacy_rate'],marker='.',c='b',s=100)
plt.ticklabel_format(style='plain',axis='y')
plt.xlabel('State',size=12)
plt.ylabel('Illiteracy rate',size=12)
plt.show()
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.

# %% [markdown]
# ## Analysis of the top 10 most populated states

# %%
r=%sql select * from(select state,sum(population)as total_population,sum(literate)as total_literate,sum(male_literate)as male_literate,sum(female_literate)as female_literate,sum(workers)as total_workers,sum(male_workers)as male_workers,sum(female_workers)as female_workers,sum(sc)as total_sc,sum(st)as total_st from(select d1.state,d2.population,d2.literate,d2.male_literate,d2.female_literate,d2.workers,d2.male_workers,d2.female_workers,d2.sc,d2.st from dataset1 d1 inner join dataset2 d2 on d1.district=d2.district_name)group by state order by total_population desc)where rownum<=10
df=r.DataFrame()
df
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
#             state  total_population  total_literate  male_literate  \
# 0   Uttar Pradesh         185756690       106704588       63539671
# 1     Maharashtra         113322979        81462909       45258393
# 2           Bihar         101074979        51811157       31081433
# 3     West Bengal          91276115        61538281       33818810
# 4  Andhra Pradesh          81698308        48839994       27256544
# 5      Tamil Nadu          72147030        51837507       28040491
# 6       Rajasthan          71757578        40206841       24809793
# 7  Madhya Pradesh          67681327        40190287       23594631
# 8       Karnataka          61350527        40734241       22562547
# 9         Gujarat          52499821        36368896       20649792
#
#    female_literate  total_workers  male_workers  female_workers  total_sc  \
# 0         43164917       61199207      46367877        14831330  38221748
# ...

# %%
plt.figure(figsize=(13,5))
plt.title('% of male and female literates in the top 10 most populated states',size=15)
plt.plot(df['state'],(df['male_literate']/df['total_literate'])*100,color='g',label='% of male literate')
plt.plot(df['state'],(df['female_literate']/df['total_literate'])*100,color='brown',linestyle=':',linewidth=2,label='% of female literate')
plt.legend(loc='lower right')
plt.show()

# %%
plt.figure(figsize=(13,5))
plt.title('% of male and female workers in the top 10 most populated states',size=15)
plt.plot(df['state'],(df['male_workers']/df['total_workers'])*100,color='orange',label='% of male workers')
plt.plot(df['state'],(df['female_workers']/df['total_workers'])*100,color='b',linestyle=':',linewidth=2,label='% of female workers')
plt.legend(loc='lower right')
plt.show()

# %%
plt.figure(figsize=(13,5))
plt.title('% of SC and ST in the top 10 most populated states',size=15)
plt.plot(df['state'],(df['total_sc']/df['total_population'])*100,color='r',label='% of SC')
plt.plot(df['state'],(df['total_st']/df['total_population'])*100,color='g',linestyle=':',linewidth=2,label='% of ST')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## District-wise Indian population in the censuses of 2001 and 2011

# %%
# %%sql
# select d1.state,d1.district,round((d2.population/(1+d1.growth))) as
# population_in_census_2001,d2.population as population_in_census_2011 from
# dataset1 d1 inner join dataset2 d2 on d1.district=d2.district_name
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Haryana', 'Gurgaon', 870363, 1514432),
#  ('Haryana', 'Karnal', 1275698, 1505324),
#  ('Haryana', 'Sonipat', 1283187, 1450001),
#  ('Haryana', 'Jind', 1191207, 1334152),
#  ('Haryana', 'Sirsa', 1116542, 1295189),
#  ('Haryana', 'Yamunanagar', 1037782, 1214205),
#  ('Haryana', 'Panipat', 964350, 1205437),
#  ('Haryana', 'Ambala', 1016532, 1128350),
#  ('Haryana', 'Mewat', 789321, 1089263),
#  ('Haryana', 'Kaithal', 942372, 1074304),
#  ('Haryana', 'Rohtak', 939119, 1061204),
#  ('Haryana', 'Palwal', 827546, 1042708),
#  ('Haryana', 'Kurukshetra', 824491, 964655),
#  ('Haryana', 'Jhajjar', 879271, 958405),
#  ('Haryana', 'Fatehabad', 805138, 942011),
#  ('Haryana', 'Mahendragarh', 816007, 922088),
#  ('Haryana', 'Rewari', 762993, 900332),
#  ('Haryana', 'Panchkula', 467744, 561293),
#  ('Himachal Pradesh', 'Kangra', 1336350, 1510075),
#  ('Himachal Pradesh', 'Mandi', 900700, 999777),
# ...

# %% [markdown]
# ### Creation of view 'database'

# %%
# %%sql
# create or replace view database as
# (select state,sum(population_in_census_2001) as population_in_census_2001,sum(population_in_census_2011) as
# population_in_census_2011 from
# (select d1.state,d1.district,round((d2.population/(1+d1.growth))) as
# population_in_census_2001,d2.population as population_in_census_2011 from
# dataset1 d1 inner join dataset2 d2 on d1.district=d2.district_name) group by state)
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# []

# %% [markdown]
# ## State-wise Indian population in censuses 2001 and 2011

# %%
# %sql select * from database
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Jammu and Kashmir', 9717040, 12015583),
#  ('Maharashtra', 96864352, 113322979),
#  ('Madhya Pradesh', 56246184, 67681327),
#  ('Orissa', 36809371, 41974218),
#  ('Bihar', 80702073, 101074979),
#  ('Chandigarh', 902094, 1055450),
#  ('Haryana', 21134924, 25351462),
#  ('Himachal Pradesh', 9419106, 10600952),
#  ('Jharkhand', 26098867, 31923078),
#  ('Rajasthan', 59099301, 71757578),
#  ('Tamil Nadu', 62376905, 72147030),
#  ('Chhattisgarh', 21725936, 26354956),
#  ('Delhi', 179752, 142004),
#  ('Gujarat', 44063507, 52499821),
#  ('Manipur', 2290351, 2855794),
#  ('Mizoram', 887530, 1097206),
#  ('Nagaland', 1047512, 1978502),
#  ('Puducherry', 239238, 297664),
#  ('Tripura', 3196246, 3673917),
#  ('Goa', 1345064, 1458545),
#  ('Karnataka', 53067261, 61350527),
#  ('Uttar Pradesh', 154641120, 185756690),
#  ('Andhra Pradesh', 73657414, 81698308),
#  ('Arunachal Pradesh', 974615, 1207154),
# ...

# %%
r=%sql select * from database where state in(select * from(select state from database order by population_in_census_2011 desc) where rownum<=10)
df=r.DataFrame()
plt.figure(figsize=(15,6))
plt.title('State-wise population trends of the top 10 populated Indian states in the 2001 and 2011 censuses',fontsize=15)
plt.plot(df['state'],df['population_in_census_2001'],label='population_in_census_2001')
plt.plot(df['state'],df['population_in_census_2011'],label='population_in_census_2011')
plt.ticklabel_format(style='plain',axis='y')
plt.legend()
plt.show()
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.

# %% [markdown]
# ## Population of India in censuses 2001 and 2011

# %%
# %%sql
# select sum(population_in_census_2001)as population_in_census_2001,sum(population_in_census_2011)as population_in_census_2011
# from database
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [(987986585, 1162711538)]

# %%
r=%sql select sum(population_in_census_2001)as population_in_census_2001,sum(population_in_census_2011)as population_in_census_2011 from database
df=r.DataFrame()
l=[]
l.append(df.loc[0,'population_in_census_2001'])
l.append(df.loc[0,'population_in_census_2011'])
plt.title('Indian Population',size=15)
plt.bar(['population_in_census_2001','population_in_census_2011'],l,color=['grey','pink'],edgecolor='k',width=0.5)
plt.ticklabel_format(style='plain',axis='y')
plt.show()
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.

# %% [markdown]
# ## Top 3 districts of each state in literacy rate

# %%
# %%sql
# select * from
# (select state,district,literacy as literacy_rate, rank() over(partition by state order by literacy desc)as rank from dataset1)
# where rank in (1,2,3)
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Andaman And Nicobar Islands', 'South Andaman', Decimal('89.13'), 1),
#  ('Andaman And Nicobar Islands', 'North And Middle Andaman', Decimal('83.91'), 2),
#  ('Andaman And Nicobar Islands', 'Nicobars', Decimal('78.06'), 3),
#  ('Andhra Pradesh', 'Hyderabad', Decimal('83.25'), 1),
#  ('Andhra Pradesh', 'Rangareddy', Decimal('75.87'), 2),
#  ('Andhra Pradesh', 'West Godavari', Decimal('74.63'), 3),
#  ('Arunachal Pradesh', 'Papumpare', Decimal('79.95'), 1),
#  ('Arunachal Pradesh', 'Lower Subansiri', Decimal('74.35'), 2),
#  ('Arunachal Pradesh', 'East Siang', Decimal('72.54'), 3),
#  ('Assam', 'Kamrup Metropolitan', Decimal('88.71'), 1),
#  ('Assam', 'Jorhat', Decimal('82.15'), 2),
#  ('Assam', 'Sivasagar', Decimal('80.41'), 3),
#  ('Bihar', 'Rohtas', Decimal('73.37'), 1),
#  ('Bihar', 'Patna', Decimal('70.68'), 2),
#  ('Bihar', 'Bhojpur', Decimal('70.47'), 3),
# ...

# %% [markdown]
# ### Creating view 'v1'

# %%
# %%sql create or replace view v1 as(select * from(select state,district,literacy as literacy_rate, rank() over
# (partition by state order by literacy desc)as rank from dataset1)where rank in (1,2,3))
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# []

# %%
r1=%sql select * from v1 where lower(state)='karnataka'
df1=r1.DataFrame()
r2=%sql select * from v1 where lower(state)='west bengal'
df2=r2.DataFrame()
r3=%sql select * from v1 where lower(state)='bihar'
df3=r3.DataFrame()
r4=%sql select * from v1 where lower(state)='maharashtra'
df4=r4.DataFrame()
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
plt.title('Top 3 districts of Karnataka in literacy rate',size=13)
plt.scatter(df1['district'],df1['literacy_rate'],marker='*',c=['r','g','b'],s=100)
plt.xlabel('District',size=10)
plt.ylabel('Literacy rate',size=10)
plt.subplot(2,2,2)
plt.title('Top 3 districts of West Bengal in literacy rate',size=13)
plt.pie(df2['literacy_rate'],labels=df2['district'],autopct=lambda p:f"{p:.2f}%, {p*float(sum(df2['literacy_rate']))/100:.2f}")
plt.xlabel('District',size=10)
plt.ylabel('Literacy rate',size=10,loc='top')
plt.subplot(2,2,3)
plt.title('Top 3 districts of Bihar in literacy rate',size=13)
barplot=plt.bar(df3['district'],df3['literacy_rate'],color=['r','g','b'],edgecolor='k',width=0.5)
plt.bar_label(barplot,labels=df3['literacy_rate'],label_type='edge')
plt.xlabel('District',size=10)
plt.ylabel('Literacy rate',size=10)
plt.subplot(2,2,4)
plt.title('Top 3 districts of Maharashtra in literacy rate',size=13)
plt.plot(df4['district'],df4['literacy_rate'],color='r')
plt.xlabel('District',size=10)
plt.ylabel('Literacy rate',size=10)
plt.show()

# %% [markdown]
# ## Bottom 3 districts of each state in literacy rate

# %%
# %%sql
# select * from
# (select state,district,literacy as literacy_rate, rank() over(partition by state order by literacy)as rank from dataset1) where rank in(1,2,3)
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Andaman And Nicobar Islands', 'Nicobars', Decimal('78.06'), 1),
#  ('Andaman And Nicobar Islands', 'North And Middle Andaman', Decimal('83.91'), 2),
#  ('Andaman And Nicobar Islands', 'South Andaman', Decimal('89.13'), 3),
#  ('Andhra Pradesh', 'Mahbubnagar', Decimal('55.04'), 1),
#  ('Andhra Pradesh', 'Vizianagaram', Decimal('58.89'), 2),
#  ('Andhra Pradesh', 'Kurnool', Decimal('59.97'), 3),
#  ('Arunachal Pradesh', 'Kurung Kumey', Decimal('48.75'), 1),
#  ('Arunachal Pradesh', 'Tirap', Decimal('52.19'), 2),
#  ('Arunachal Pradesh', 'Anjaw', Decimal('56.46'), 3),
#  ('Assam', 'Dhubri', Decimal('58.34'), 1),
#  ('Assam', 'Darrang', Decimal('63.08'), 2),
#  ('Assam', 'Chirang', Decimal('63.55'), 3),
#  ('Bihar', 'Purnia', Decimal('51.08'), 1),
#  ('Bihar', 'Sitamarhi', Decimal('52.05'), 2),
#  ('Bihar', 'Katihar', Decimal('52.24'), 3),
#  ('Chandigarh', 'Chandigarh', Decimal('86.05'), 1),
# ...

# %% [markdown]
# ## Top 3 districts of each state in sex ratio

# %%
# %%sql
# select * from
# (select state,district,sexratio, rank() over(partition by state order by sexratio desc)as rank from dataset1)
# where rank in (1,2,3)
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Andaman And Nicobar Islands', 'North And Middle Andaman', 925, 1),
#  ('Andaman And Nicobar Islands', 'South Andaman', 871, 2),
#  ('Andaman And Nicobar Islands', 'Nicobars', 777, 3),
#  ('Andhra Pradesh', 'Nizamabad', 1040, 1),
#  ('Andhra Pradesh', 'Vizianagaram', 1019, 2),
#  ('Andhra Pradesh', 'Srikakulam', 1015, 3),
#  ('Arunachal Pradesh', 'Kurung Kumey', 1032, 1),
#  ('Arunachal Pradesh', 'East Kameng', 1029, 2),
#  ('Arunachal Pradesh', 'Upper Subansiri', 998, 3),
#  ('Assam', 'Baksa', 974, 1),
#  ('Assam', 'Udalguri', 973, 2),
#  ('Assam', 'Chirang', 969, 3),
#  ('Bihar', 'Gopalganj', 1021, 1),
#  ('Bihar', 'Siwan', 988, 2),
#  ('Bihar', 'Saran', 954, 3),
#  ('Chandigarh', 'Chandigarh', 818, 1),
#  ('Chhattisgarh', 'Bastar', 1023, 1),
#  ('Chhattisgarh', 'Dantewada', 1020, 2),
#  ('Chhattisgarh', 'Mahasamund', 1017, 3),
#  ('Dadra and Nagar Haveli', 'Dadra and Nagar Haveli', 774, 1),
# ...

# %% [markdown]
# ### Creating view 'v2'

# %%
# %%sql create or replace view v2 as
# (select * from
# (select state,district,sexratio, rank() over(partition by state order by sexratio desc)as rank from dataset1)
# where rank in (1,2,3))
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# []

# %%
r1=%sql select * from v2 where lower(state)='tamil nadu'
df5=r1.DataFrame()
r2=%sql select * from v2 where lower(state)='assam'
df6=r2.DataFrame()
r3=%sql select * from v2 where lower(state)='uttar pradesh'
df7=r3.DataFrame()
r4=%sql select * from v2 where lower(state)='madhya pradesh'
df8=r4.DataFrame()
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
plt.title('Top 3 districts of Tamil Nadu in sex ratio',size=13)
plt.pie(df5['sexratio'],labels=df5['district'],autopct=lambda p:f"{p:.2f}%, {p*float(sum(df5['sexratio']))/100:.0f}",colors=['violet','y','grey'])
plt.xlabel('District',size=10)
plt.ylabel('Sex ratio',size=10,loc='top')
plt.subplot(2,2,2)
plt.title('Top 3 districts of Assam in sex ratio',size=13)
plt.scatter(df6['district'],df6['sexratio'],marker='.',c=['grey','y','g'],s=120)
plt.xlabel('District',size=10)
plt.ylabel('Sex ratio',size=10)
plt.subplot(2,2,3)
plt.title('Top 3 districts of Uttar Pradesh in sex ratio',size=13)
plt.plot(df7['district'],df7['sexratio'],color='g',linestyle=':',linewidth=2)
plt.xlabel('District',size=10)
plt.ylabel('Sex ratio',size=10)
plt.subplot(2,2,4)
plt.title('Top 3 districts of Madhya Pradesh in sex ratio',size=13)
barplot=plt.bar(df8['district'],df8['sexratio'],color=['grey','b','y'],edgecolor='k',width=0.5)
plt.bar_label(barplot,labels=df8['sexratio'],label_type='edge')
plt.xlabel('District',size=10)
plt.ylabel('Sex ratio',size=10)
plt.show()

# %% [markdown]
# ## Bottom 3 districts of each state in sex ratio

# %%
# %%sql
# select * from
# (select state,district,sexratio, rank() over(partition by state order by sexratio)as rank from dataset1)
# where rank in (1,2,3)
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Andaman And Nicobar Islands', 'Nicobars', 777, 1),
#  ('Andaman And Nicobar Islands', 'South Andaman', 871, 2),
#  ('Andaman And Nicobar Islands', 'North And Middle Andaman', 925, 3),
#  ('Andhra Pradesh', 'Hyderabad', 954, 1),
#  ('Andhra Pradesh', 'Rangareddy', 961, 2),
#  ('Andhra Pradesh', 'Mahbubnagar', 977, 3),
#  ('Andhra Pradesh', 'Anantapur', 977, 3),
#  ('Arunachal Pradesh', 'Tawang', 714, 1),
#  ('Arunachal Pradesh', 'Dibang Valley', 813, 2),
#  ('Arunachal Pradesh', 'West Kameng', 819, 3),
#  ('Assam', 'Dima Hasao', 932, 1),
#  ('Assam', 'Kamrup Metropolitan', 936, 2),
#  ('Assam', 'Kamrup', 949, 3),
#  ('Assam', 'Nalbari', 949, 3),
#  ('Bihar', 'Munger', 876, 1),
#  ('Bihar', 'Bhagalpur', 880, 2),
#  ('Bihar', 'Khagaria', 886, 3),
#  ('Chandigarh', 'Chandigarh', 818, 1),
#  ('Chhattisgarh', 'Korea', 968, 1),
#  ('Chhattisgarh', 'Korba', 969, 2),
#  ('Chhattisgarh', 'Bilaspur', 971, 3),
# ...

# %% [markdown]
# ## Top 3 districts of each state in growth rate

# %%
# %%sql
# select * from
# (select state,district,growth as growth_rate, rank() over(partition by state order by growth desc)as rank from dataset1)
# where rank in (1,2,3)
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Andaman And Nicobar Islands', 'South Andaman', Decimal('0.14'), 1),
#  ('Andaman And Nicobar Islands', 'North And Middle Andaman', 0, 2),
#  ('Andaman And Nicobar Islands', 'Nicobars', Decimal('-0.12'), 3),
#  ('Andhra Pradesh', 'Rangareddy', Decimal('0.48'), 1),
#  ('Andhra Pradesh', 'Mahbubnagar', Decimal('0.15'), 2),
#  ('Andhra Pradesh', 'Kurnool', Decimal('0.15'), 2),
#  ('Arunachal Pradesh', 'Kurung Kumey', Decimal('1.17'), 1),
#  ('Arunachal Pradesh', 'Upper Subansiri', Decimal('0.51'), 2),
#  ('Arunachal Pradesh', 'Lower Subansiri', Decimal('0.49'), 3),
#  ('Assam', 'Dhubri', Decimal('0.24'), 1),
#  ('Assam', 'Morigaon', Decimal('0.23'), 2),
#  ('Assam', 'Goalpara', Decimal('0.23'), 2),
#  ('Bihar', 'Madhepura', Decimal('0.31'), 1),
#  ('Bihar', 'Khagaria', Decimal('0.3'), 2),
#  ('Bihar', 'Kishanganj', Decimal('0.3'), 2),
#  ('Bihar', 'Araria', Decimal('0.3'), 2),
# ...

# %% [markdown]
# ### Creating view 'v3'

# %%
# %%sql create or replace view v3 as
# (select * from
# (select state,district,growth as growth_rate, rank() over(partition by state order by growth desc)as rank from dataset1)
# where rank in (1,2,3))
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# []

# %%
r1=%sql select * from v3 where lower(state)='andhra pradesh'
df9=r1.DataFrame()
r2=%sql select * from v3 where lower(state)='punjab'
df10=r2.DataFrame()
r3=%sql select * from v3 where lower(state)='gujarat'
df11=r3.DataFrame()
r4=%sql select * from v3 where lower(state)='rajasthan'
df12=r4.DataFrame()
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
plt.title('Top 3 districts of Andhra Pradesh in growth rate',size=13)
plt.scatter(df9['district'],df9['growth_rate']*100,marker='*',c=['b','r','y'],s=100)
plt.xlabel('District',size=10)
plt.ylabel('Growth rate',size=10)
plt.subplot(2,2,2)
plt.title('Top 3 districts of Punjab in growth rate',size=13)
plt.pie(df10['growth_rate'],labels=df10['district'],autopct=lambda p:f"{p:.2f}%, {(p*float(sum(df10['growth_rate']))/100)*100:.2f}",colors=['b','y','r'])
plt.xlabel('District',size=10)
plt.ylabel('Growt rate',size=10,loc='top')
plt.subplot(2,2,3)
plt.title('Top 3 districts of Gujarat in growth rate',size=13)
barplot=plt.bar(df11['district'],df11['growth_rate']*100,color=['b','y','g'],edgecolor='k',width=0.5)
plt.bar_label(barplot,labels=df11['growth_rate']*100,label_type='edge')
plt.xlabel('District',size=10)
plt.ylabel('Growth rate',size=10)
plt.subplot(2,2,4)
plt.title('Top 3 districts of Rajasthan in growth rate',size=13)
plt.plot(df12['district'],df12['growth_rate']*100,color='b',linestyle=':',linewidth=2)
plt.xlabel('District',size=10)
plt.ylabel('Growth rate',size=10)
plt.show()

# %% [markdown]
# ## Bottom 3 districts of each state in growth rate

# %%
# %%sql
# select * from
# (select state,district,growth as growth_rate, rank() over(partition by state order by growth)as rank from dataset1)
# where rank in (1,2,3)
# Out:
#  * oracle+cx_oracle://Projects:***@127.0.0.1:8080/
# 0 rows affected.
# [('Andaman And Nicobar Islands', 'Nicobars', Decimal('-0.12'), 1),
#  ('Andaman And Nicobar Islands', 'North And Middle Andaman', 0, 2),
#  ('Andaman And Nicobar Islands', 'South Andaman', Decimal('0.14'), 3),
#  ('Andhra Pradesh', 'Hyderabad', Decimal('0.03'), 1),
#  ('Andhra Pradesh', 'Vizianagaram', Decimal('0.04'), 2),
#  ('Andhra Pradesh', 'West Godavari', Decimal('0.04'), 2),
#  ('Arunachal Pradesh', 'Upper Siang', Decimal('0.06'), 1),
#  ('Arunachal Pradesh', 'Lower Dibang Valley', Decimal('0.07'), 2),
#  ('Arunachal Pradesh', 'West Siang', Decimal('0.08'), 3),
#  ('Assam', 'Kokrajhar', Decimal('0.05'), 1),
#  ('Assam', 'Sivasagar', Decimal('0.09'), 2),
#  ('Assam', 'Jorhat', Decimal('0.09'), 2),
#  ('Bihar', 'Darbhanga', Decimal('0.19'), 1),
#  ('Bihar', 'Arwal', Decimal('0.19'), 1),
#  ('Bihar', 'Gopalganj', Decimal('0.19'), 1),
#  ('Chandigarh', 'Chandigarh', Decimal('0.17'), 1),
# ...
